# %%
# !pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.0 MB ? eta -:--:--
#    - -------------------------------------- 0.8/24.0 MB 2.0 MB/s eta 0:00:12
#    - -------------------------------------- 1.0/24.0 MB 2.0 MB/s eta 0:00:12
#    -- ------------------------------------- 1.3/24.0 MB 1.6 MB/s eta 0:00:15
#    -- ------------------------------------- 1.6/24.0 MB 1.4 MB/s eta 0:00:16
#    --- ------------------------------------ 1.8/24.0 MB 1.4 MB/s eta 0:00:16
#    --- ------------------------------------ 2.1/24.0 MB 1.4 MB/s eta 0:00:16
#    ---- ----------------------------------- 2.6/24.0 MB 1.5 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.9/24.0 MB 1.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 3.1/24.0 MB 1.4 MB/s eta 0:00:15
#    ----- ---------------------------------- 3.4/24.0 MB 1.5 MB/s eta 0:00:14
# ...

# %%
import gensim

# %%
from gensim.models import Word2Vec, keyedvectors

# %%
import gensim.downloader as api
wv = api.load("word2vec-google-news-300")
wv_king = wv["king"]

# %%
wv_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
wv_king.shape
# Out:
# (300,)

# %%
gig_wv = api.load("glove-wiki-gigaword-100")

# %%
gig_king = gig_wv["king"]

# %%
gig_king
# Out:
# array([-0.32307 , -0.87616 ,  0.21977 ,  0.25268 ,  0.22976 ,  0.7388  ,
#        -0.37954 , -0.35307 , -0.84369 , -1.1113  , -0.30266 ,  0.33178 ,
#        -0.25113 ,  0.30448 , -0.077491, -0.89815 ,  0.092496, -1.1407  ,
#        -0.58324 ,  0.66869 , -0.23122 , -0.95855 ,  0.28262 , -0.078848,
#         0.75315 ,  0.26584 ,  0.3422  , -0.33949 ,  0.95608 ,  0.065641,
#         0.45747 ,  0.39835 ,  0.57965 ,  0.39267 , -0.21851 ,  0.58795 ,
#        -0.55999 ,  0.63368 , -0.043983, -0.68731 , -0.37841 ,  0.38026 ,
#         0.61641 , -0.88269 , -0.12346 , -0.37928 , -0.38318 ,  0.23868 ,
#         0.6685  , -0.43321 , -0.11065 ,  0.081723,  1.1569  ,  0.78958 ,
#        -0.21223 , -2.3211  , -0.67806 ,  0.44561 ,  0.65707 ,  0.1045  ,
#         0.46217 ,  0.19912 ,  0.25802 ,  0.057194,  0.53443 , -0.43133 ,
#        -0.34311 ,  0.59789 , -0.58417 ,  0.068995,  0.23944 , -0.85181 ,
#         0.30379 , -0.34177 , -0.25746 , -0.031101, -0.16285 ,  0.45169 ,
# ...

# %%
gig_king.shape
# Out:
# (100,)

# %%
print(list(api.info()["models"].keys()))

# These are different pre-trained model which we can also use but they have less in dimensions
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
wv["cricket"]
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
wv["raw"]
# Out:
# array([ 8.69140625e-02,  6.20117188e-02,  1.89453125e-01, -3.37219238e-03,
#        -1.30859375e-01,  2.49023438e-01,  5.27343750e-02, -2.75390625e-01,
#        -1.48437500e-01,  3.04687500e-01, -2.22656250e-01, -3.96484375e-01,
#        -1.46484375e-01, -9.13085938e-02, -1.51367188e-01, -1.49536133e-02,
#        -9.61914062e-02,  1.58203125e-01, -2.43164062e-01, -2.69531250e-01,
#        -1.09863281e-01, -6.68945312e-02, -1.05957031e-01,  1.16210938e-01,
#        -3.95507812e-02, -2.63671875e-01,  8.39843750e-02,  1.92382812e-01,
#        -1.59912109e-02, -2.05078125e-02, -3.19824219e-02,  3.67187500e-01,
#        -3.93066406e-02,  4.07714844e-02, -2.59765625e-01,  3.58886719e-02,
#        -2.40234375e-01, -4.05883789e-03, -1.34765625e-01,  1.05957031e-01,
#         2.67333984e-02, -1.73828125e-01,  1.83593750e-01,  2.34375000e-01,
#        -1.09375000e-01, -3.27148438e-02, -3.80859375e-02,  2.13867188e-01,
# ...

# %%
wv.most_similar("cricket")
# Out:
# [('cricketing', 0.8372227549552917),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068487048149109),
#  ('Twenty##', 0.762426495552063),
#  ('Cricket', 0.7541398406028748),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316358685493469),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.698798656463623)]

# %%
gig_wv.most_similar("cricket")
# Out:
# [('rugby', 0.7827098369598389),
#  ('twenty20', 0.7362943291664124),
#  ('england', 0.7173773050308228),
#  ('indies', 0.715782105922699),
#  ('cricketers', 0.7132173180580139),
#  ('football', 0.6659637093544006),
#  ('zealand', 0.6606224179267883),
#  ('matches', 0.6509107351303101),
#  ('bowling', 0.6504763960838318),
#  ('wc2003-wis', 0.6422653198242188)]

# %%
wv.most_similar("happy")
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626911163330078),
#  ('overjoyed', 0.6599287390708923),
#  ('thrilled', 0.6514049768447876),
#  ('satisfied', 0.6437950134277344),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665882110596)]

# %%
wv.most_similar("sad")
# Out:
# [('saddening', 0.7273086905479431),
#  ('Sad', 0.6610826849937439),
#  ('saddened', 0.6604382395744324),
#  ('heartbreaking', 0.6573508977890015),
#  ('disheartening', 0.6507318019866943),
#  ('Meny_Friedman', 0.6487058401107788),
#  ('parishioner_Pat_Patello', 0.6475861072540283),
#  ('saddens_me', 0.6407118439674377),
#  ('distressing', 0.6399092674255371),
#  ('reminders_bobbing', 0.6357713341712952)]

# %%
wv.most_similar("saddening")
# Out:
# [('sad', 0.7273086309432983),
#  ('distressing', 0.696329653263092),
#  ('disheartening', 0.6739423274993896),
#  ('shocking', 0.6282068490982056),
#  ('saddens_me', 0.6028542518615723),
#  ('shameful', 0.6016943454742432),
#  ('regrettable', 0.5831369757652283),
#  ('disturbing', 0.5826939940452576),
#  ('unfortunate', 0.5810596346855164),
#  ('disconcerting', 0.5663262605667114)]

# %%
gig_wv.most_similar("happy")
# Out:
# [("'m", 0.8413287401199341),
#  ('feel', 0.81325763463974),
#  ("'re", 0.8048083186149597),
#  ('i', 0.7938276529312134),
#  ("'ll", 0.7916272878646851),
#  ('really', 0.7903971076011658),
#  ('glad', 0.7833361029624939),
#  ('good', 0.7821646332740784),
#  ('we', 0.7808916568756104),
#  ('sure', 0.7788466811180115)]

# %%
gig_wv.most_similar("sad")
# Out:
# [('sorry', 0.7547181248664856),
#  ('awful', 0.7284239530563354),
#  ('tragic', 0.7238599061965942),
#  ('horrible', 0.7049302458763123),
#  ('happy', 0.6801136136054993),
#  ('heartbreaking', 0.6760851740837097),
#  ('poignant', 0.6715506911277771),
#  ('scary', 0.6703184843063354),
#  ('terrible', 0.6671074628829956),
#  ('unfortunate', 0.662224292755127)]

# %%
wv.similarity("hockey","sports")
# Out:
# 0.5354152

# %%
wv.similarity("happy","sad")
# Out:
# 0.5354614

# %%
gig_wv.similarity("happy","sad")
# Out:
# 0.6801137

# %%
wv.similarity("foreplay","sex")  # no filter lol
# Out:
# 0.47513795

# %%
vec = wv["king"] - wv["man"] + wv["women"]
vec
# Out:
# array([-0.33984375,  0.06298828, -0.00994873,  0.3305664 ,  0.10327148,
#        -0.25854492,  0.19677734, -0.32476807, -0.15917969,  0.45752716,
#        -0.39208984, -0.22460938,  0.02929688,  0.31982422, -0.0958252 ,
#        -0.05932617,  0.01855469, -0.03945923,  0.01101685,  0.33984375,
#         0.10351562,  0.14396667, -0.07641602,  0.06640625, -0.10839844,
#        -0.1953125 , -0.3564453 , -0.02124023, -0.16503906, -0.16247559,
#        -0.05519104, -0.1003418 ,  0.01464844,  0.23449707, -0.26611328,
#        -0.07080078, -0.26904297, -0.00292969, -0.06738281, -0.02050781,
#         0.04418945, -0.09326172,  0.12304688,  0.10626221,  0.10290527,
#         0.01660156, -0.10791016, -0.0065918 ,  0.17578125,  0.10028076,
#         0.22363281, -0.05761719, -0.31743622,  0.3922119 , -0.35498047,
#        -0.23643494, -0.01074219, -0.01334572, -0.15283203, -0.00793457,
#         0.08203125,  0.09985352,  0.003479  ,  0.11608887,  0.14550781,
# ...

# %%
wv.most_similar([vec])
# Out:
# [('king', 0.6478992700576782),
#  ('queen', 0.5354938507080078),
#  ('women', 0.5233659744262695),
#  ('kings', 0.5162314176559448),
#  ('queens', 0.499536395072937),
#  ('kumaris', 0.4923847019672394),
#  ('princes', 0.4623327851295471),
#  ('monarch', 0.4528028666973114),
#  ('monarchy', 0.429317444562912),
#  ('kings_princes', 0.42342403531074524)]
